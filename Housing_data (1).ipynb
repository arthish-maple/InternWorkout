# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
housing_data = pd.read_csv("/content/Housing (2).csv")

# %%
housing_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
housing_data.shape
# Out:
# (545, 13)

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
housing_data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
#visualize the numeric variable

#check whether linear model makes sense or not
#which means the target variable should have some linear relation with other variable
#check multicolinearity

sns.pairplot(housing_data)
plt.show()

# %%
#categorical variable
#to visualize categorical variable and a numeric variable you will need box plot

plt.figure(figsize = (20,12))
plt.subplot(2,3,1)
sns.boxplot(x = 'mainroad' , y = 'price', data = housing_data)

plt.subplot(2,3,2)
sns.boxplot(x = 'guestroom' , y = 'price', data = housing_data)

plt.subplot(2,3,3)
sns.boxplot(x = 'basement' , y = 'price', data = housing_data)

plt.subplot(2,3,4)
sns.boxplot(x = 'hotwaterheating' , y = 'price', data = housing_data)

plt.subplot(2,3,5)
sns.boxplot(x = 'airconditioning' , y = 'price', data = housing_data)

plt.subplot(2,3,6)
sns.boxplot(x = 'furnishingstatus' , y = 'price', data = housing_data)

plt.show()

# %% [markdown]
# ### **Data Preparation**

# %%
#convert yest/no to binary

varlist = ['mainroad' , 'guestroom' , 'basement', 'hotwaterheating' ,'airconditioning' , 'prefarea' ]

housing_data[varlist] = housing_data[varlist].apply(lambda x : x.map({'yes' : 1 , 'no' :0}))

# %%
housing_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
#dummy vairable

dummy = pd.get_dummies(housing_data['furnishingstatus'] , drop_first= True)
dummy = dummy.apply(lambda x : x.map({True : 1 , False :0}))
dummy.head()
# Out:
#    semi-furnished  unfurnished
# 0               0            0
# 1               0            0
# 2               1            0
# 3               0            0
# 4               0            0

# %%
#concat the dummy with original

housing_data = pd.concat([housing_data , dummy], axis = 1)
housing_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus  semi-furnished  unfurnished
# 0        furnished               0            0
# 1        furnished               0            0
# ...

# %%
housing_data.drop(columns = "furnishingstatus" , axis = 1 , inplace = True)
housing_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    semi-furnished  unfurnished
# 0               0            0
# 1               0            0
# 2               1            0
# ...

# %%
#spliting into train and test

df_train , df_test = train_test_split(housing_data, train_size= 0.7 , random_state= 100)

print(df_train.shape , df_test.shape)
# Out:
# (381, 14) (164, 14)

# %%
#Rescaling
#standardisation or min max scaling
#it is important in multiple linear regression coeffient will be very different



# Instantiate an object

scaler = MinMaxScaler()

#except for binary variables we will be scaling all numeric variables
vars = ['area' , 'bedrooms', 'bathrooms' , 'stories' , 'parking', 'price']

#fit on data

df_train[vars] = scaler.fit_transform(df_train[vars])

df_train.head()
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 359  0.169697  0.155227       0.4        0.0  0.000000         1          0
# 19   0.615152  0.403379       0.4        0.5  0.333333         1          0
# 159  0.321212  0.115628       0.4        0.5  0.000000         1          1
# 35   0.548133  0.454417       0.4        0.5  1.000000         1          0
# 28   0.575758  0.538015       0.8        0.5  0.333333         1          0
#
#      basement  hotwaterheating  airconditioning   parking  prefarea  \
# 359         0                0                0  0.333333         0
# 19          0                0                1  0.333333         1
# 159         1                0                1  0.000000         0
# 35          0                0                1  0.666667         0
# 28          1                1                0  0.666667         0
#
#      semi-furnished  unfurnished
# 359               0            1
# ...

# %% [markdown]
# ## Training The Model

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(df_train.corr() , annot = True)
plt.show()

# %%
y_train = df_train.pop('price')
X_train = df_train

# %%
X_train
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 359  0.155227       0.4        0.0  0.000000         1          0         0
# 19   0.403379       0.4        0.5  0.333333         1          0         0
# 159  0.115628       0.4        0.5  0.000000         1          1         1
# 35   0.454417       0.4        0.5  1.000000         1          0         0
# 28   0.538015       0.8        0.5  0.333333         1          0         1
# ..        ...       ...        ...       ...       ...        ...       ...
# 526  0.118268       0.2        0.0  0.000000         1          0         0
# 53   0.291623       0.4        0.5  1.000000         1          0         0
# 350  0.139388       0.2        0.0  0.333333         1          0         0
# 79   0.366420       0.4        0.5  0.666667         1          1         0
# 520  0.516015       0.2        0.0  0.000000         1          0         0
#
# ...

# %%
y_train
# Out:
# 359    0.169697
# 19     0.615152
# 159    0.321212
# 35     0.548133
# 28     0.575758
#          ...
# 526    0.048485
# 53     0.484848
# 350    0.175758
# 79     0.424242
# 520    0.060606
# Name: price, Length: 381, dtype: float64

# %%
# statistical significance of the variable
# VIF

# add a constant
X_train_sm = sm.add_constant(X_train)

#create model

lr = sm.OLS(y_train , X_train_sm)

#fit

lr_model = lr.fit()

lr_model.summary()

#p values exceeds 0.05 remove highest variable
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     60.40
# Date:                Wed, 19 Jun 2024   Prob (F-statistic):           8.83e-83
# Time:                        16:12:52   Log-Likelihood:                 381.79
# No. Observations:                 381   AIC:                            -735.6
# Df Residuals:                     367   BIC:                            -680.4
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
#Vif (Variance Inflation Factor ) explains how collinear the variable is with other variable

vif = pd.DataFrame()
vif['Features'] = X_train.columns

vif['VIF'] = [variance_inflation_factor(X_train.values , i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'] , 2)

vif = vif.sort_values(by = "VIF" , ascending = False)

vif
# Out:
#            Features   VIF
# 1          bedrooms  7.33
# 4          mainroad  6.02
# 0              area  4.67
# 3           stories  2.70
# 11   semi-furnished  2.19
# 9           parking  2.12
# 6          basement  2.02
# 12      unfurnished  1.82
# 8   airconditioning  1.77
# 2         bathrooms  1.67
# 10         prefarea  1.51
# 5         guestroom  1.47
# 7   hotwaterheating  1.14

# %%
#drop high p value
X = X_train.drop('semi-furnished' , axis = 1)

# %%
X_train_sm = sm.add_constant(X)

#create another model

lr = sm.OLS(y_train , X_train_sm)

#fit

lr_model = lr.fit()

lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     65.61
# Date:                Wed, 19 Jun 2024   Prob (F-statistic):           1.07e-83
# Time:                        16:12:52   Log-Likelihood:                 381.79
# No. Observations:                 381   AIC:                            -737.6
# Df Residuals:                     368   BIC:                            -686.3
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = X.columns

vif['VIF'] = [variance_inflation_factor(X.values , i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'] , 2)

vif = vif.sort_values(by = "VIF" , ascending = False)

vif
# Out:
#            Features   VIF
# 1          bedrooms  6.59
# 4          mainroad  5.68
# 0              area  4.67
# 3           stories  2.69
# 9           parking  2.12
# 6          basement  2.01
# 8   airconditioning  1.77
# 2         bathrooms  1.67
# 10         prefarea  1.51
# 5         guestroom  1.47
# 11      unfurnished  1.40
# 7   hotwaterheating  1.14

# %%
X = X.drop('bedrooms' , axis = 1)

# %%
X_train_sm = sm.add_constant(X)

#create another model

lr = sm.OLS(y_train , X_train_sm)

#fit

lr_model = lr.fit()

lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.680
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     71.31
# Date:                Wed, 19 Jun 2024   Prob (F-statistic):           2.73e-84
# Time:                        16:12:52   Log-Likelihood:                 380.96
# No. Observations:                 381   AIC:                            -737.9
# Df Residuals:                     369   BIC:                            -690.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = X.columns

vif['VIF'] = [variance_inflation_factor(X.values , i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'] , 2)

vif = vif.sort_values(by = "VIF" , ascending = False)

vif
# Out:
#            Features   VIF
# 3          mainroad  4.79
# 0              area  4.55
# 2           stories  2.23
# 8           parking  2.10
# 5          basement  1.87
# 7   airconditioning  1.76
# 1         bathrooms  1.61
# 9          prefarea  1.50
# 4         guestroom  1.46
# 10      unfurnished  1.33
# 6   hotwaterheating  1.12

# %%
#Residual Analysis

y_train_pred = lr_model.predict(X_train_sm)

# %%
res = y_train - y_train_pred

sns.distplot(res)
plt.show()
# Out:
# <ipython-input-29-c315b115f305>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(res)

# %%
r2_score(y_true= y_train, y_pred= y_train_pred)
# Out:
# 0.6800930630265903

# %% [markdown]
# # Prediction And evaluation on test set

# %%
#dont fit on test set
vars = ['area' , 'bedrooms', 'bathrooms' , 'stories' , 'parking', 'price']

#fit on data

df_test[vars] = scaler.transform(df_test[vars])

df_test.head()
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 265  0.229697  0.091869       0.4        0.0  0.333333         1          0
# 54   0.484848  0.366420       0.4        0.5  0.333333         1          1
# 171  0.303030  0.742080       0.4        0.0  0.000000         1          0
# 244  0.242424  0.306582       0.4        0.0  0.333333         1          1
# 268  0.227879  0.274023       0.6        0.0  0.333333         1          0
#
#      basement  hotwaterheating  airconditioning   parking  prefarea  \
# 265         0                0                0  0.000000         1
# 54          0                0                1  0.333333         0
# 171         0                0                0  0.333333         1
# 244         1                0                0  0.000000         1
# 268         0                0                1  0.000000         0
#
#      semi-furnished  unfurnished
# 265               1            0
# ...

# %%
df_test.describe()
# Out:
#             price        area    bedrooms   bathrooms     stories    mainroad  \
# count  164.000000  164.000000  164.000000  164.000000  164.000000  164.000000
# mean     0.263176    0.298548    0.408537    0.158537    0.268293    0.865854
# std      0.172077    0.211922    0.147537    0.281081    0.276007    0.341853
# min      0.006061   -0.016367    0.200000    0.000000    0.000000    0.000000
# 25%      0.142424    0.148011    0.400000    0.000000    0.000000    1.000000
# 50%      0.226061    0.259724    0.400000    0.000000    0.333333    1.000000
# 75%      0.346970    0.397439    0.400000    0.500000    0.333333    1.000000
# max      0.909091    1.263992    0.800000    1.500000    1.000000    1.000000
#
#         guestroom    basement  hotwaterheating  airconditioning     parking  \
# count  164.000000  164.000000       164.000000       164.000000  164.000000
# mean     0.195122    0.347561         0.030488         0.353659    0.205285
# ...

# %%
y_test = df_test.pop('price')
X_test = df_test

# %%
#add a constant

X_test_sm = sm.add_constant(X_test)
X_test_sm.head()
# Out:
#      const      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 265    1.0  0.091869       0.4        0.0  0.333333         1          0
# 54     1.0  0.366420       0.4        0.5  0.333333         1          1
# 171    1.0  0.742080       0.4        0.0  0.000000         1          0
# 244    1.0  0.306582       0.4        0.0  0.333333         1          1
# 268    1.0  0.274023       0.6        0.0  0.333333         1          0
#
#      basement  hotwaterheating  airconditioning   parking  prefarea  \
# 265         0                0                0  0.000000         1
# 54          0                0                1  0.333333         0
# 171         0                0                0  0.333333         1
# 244         1                0                0  0.000000         1
# 268         0                0                1  0.000000         0
#
#      semi-furnished  unfurnished
# 265               1            0
# 54                1            0
# ...

# %%
X_test_sm = X_test_sm.drop(["bedrooms" , "semi-furnished"] , axis = 1)

# %%
#predict
y_test_pred = lr_model.predict(X_test_sm)

# %%
#evaluate
# the model learned in train set is able to generalize in test set r2 score

r2_score(y_true= y_test, y_pred= y_test_pred)
# Out:
# 0.6713505684480789
